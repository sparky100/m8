# %% [markdown]
# ## Import Locations file

# %%
import json

with open('locations.json') as json_file:
    data = json.load(json_file)

# %% [markdown]
# ## Normalise location data

# %%
import pandas as pd
result = pd.json_normalize(data['d2LogicalModel'])

# %% [markdown]
# ### Get Keys

# %%
result.keys()
# Out:
# Index(['@xmlns', '@xmlns$xsi', '@xmlns$xalan', '@modelBaseVersion',
#        '@xsi$schemaLocation', 'exchange.supplierIdentification.country',
#        'exchange.supplierIdentification.nationalIdentifier',
#        'payloadPublication.@lang', 'payloadPublication.@xsi$type',
#        'payloadPublication.publicationTime',
#        'payloadPublication.publicationCreator.country',
#        'payloadPublication.publicationCreator.nationalIdentifier',
#        'payloadPublication.headerInformation.confidentiality',
#        'payloadPublication.headerInformation.informationStatus',
#        'payloadPublication.measurementSiteTable.@id',
#        'payloadPublication.measurementSiteTable.measurementSiteRecord'],
#       dtype='object')

# %%
res=(result ['payloadPublication.measurementSiteTable.measurementSiteRecord'][0][:][:])

# %% [markdown]
# ### Location information from locations data

# %%
len(res)
locations=pd.json_normalize(res)
#locations=data[['@id','measurementSiteLocation.tpeglinearLocation.to.pointCoordinates.latitude','measurementSiteLocation.tpeglinearLocation.to.pointCoordinates.longitude','measurementSiteLocation.tpeglinearLocation.to.name.descriptor.value']]
locations=locations.rename(columns={'measurementSiteLocation.tpeglinearLocation.to.pointCoordinates.latitude': "toLatitude"})
locations=locations.rename(columns={'measurementSiteLocation.tpeglinearLocation.to.pointCoordinates.longitude': "toLongitude"})
locations=locations.rename(columns={'measurementSiteLocation.tpeglinearLocation.to.name.descriptor.value': "toDescription"})
locations=locations.rename(columns={'measurementSiteLocation.tpeglinearLocation.from.pointCoordinates.latitude': "fromLatitude"})
locations=locations.rename(columns={'measurementSiteLocation.tpeglinearLocation.from.pointCoordinates.longitude': "fromLongitude"})
locations=locations.rename(columns={'measurementSiteLocation.tpeglinearLocation.from.name.descriptor.value': "fromDescription"})
locations[['@id','toLatitude','toLongitude','toDescription','fromLatitude','fromLongitude','fromDescription' ]]
#data.dtypes
#data.keys()
#data.rename(columns={"measurementSiteLocation.tpeglinearLocation.to.pointCoordinates.latitude":"latitude"})
#data.keys()
locations.to_csv("locs.csv")

# %% [markdown]
# ### Get movement data

# %%
import json
import requests
#page = requests.get('https://gcc.azure-api.net/traffic/v1/movement/now?size=1500')
page=requests.get('https://gcc.azure-api.net/datextraffic/movement?format=json')
data3=page.json()
print(data3)

# Serializing json 
movementNow = json.dumps(data3, indent = 12)

with open("movementNowdataex.json", "w") as outfile:
    outfile.write(movementNow)
# Out:
# {'version': '1.0', 'encoding': 'UTF-8', 'd2LogicalModel': {'@xmlns': 'http://datex2.eu/schema/1_0/1_0', '@xmlns$xsi': 'http://www.w3.org/2001/XMLSchema-instance', '@xmlns$xalan': 'http://xml.apache.org/xslt', '@modelBaseVersion': '1.0', '@xsi$schemaLocation': 'http://datex2.eu/schema/1_0/1_0 http://datex2.eu/schema/1_0/1_0/DATEXIISchema_1_0_1_0.xsd', 'exchange': {'supplierIdentification': {'country': 'gb', 'nationalIdentifier': 'TIH Toolkit'}}, 'payloadPublication': {'@lang': 'en', '@xsi$type': 'MeasuredDataPublication', 'publicationTime': '2021-12-02T20:21:08', 'publicationCreator': {'country': 'gb', 'nationalIdentifier': 'TIH Toolkit'}, 'measurementSiteTableReference': 'SCOOT_LINK_LOCATION_TABLE', 'headerInformation': {'confidentiality': 'noRestriction', 'informationStatus': 'real'}, 'siteMeasurements': [{'measurementSiteReference': 'GH020A_B', 'measurementTimeDefault': '2021-12-02T20:20:11', 'measuredValue': [{'@index': '1', 'basicDataValue': {'@xsi$type': 'TrafficFlow', 'vehicleF
# ...

# %% [markdown]
# ## Load saved movement data file

# %%
import json
import pandas as pd
with open('movementNowdataex.json') as json_file:
    data = json.load(json_file)

# %%
len(data['d2LogicalModel']['payloadPublication']['siteMeasurements'])
# Out:
# 1033

# %%
measurements=data['d2LogicalModel']['payloadPublication']['siteMeasurements']
recordedtime=data['d2LogicalModel']['payloadPublication']['publicationTime']

# %%
measurements[0]
# Out:
# {'measurementSiteReference': 'GH020A_B',
#  'measurementTimeDefault': '2021-12-11T17:00:11',
#  'measuredValue': [{'@index': '1',
#    'basicDataValue': {'@xsi$type': 'TrafficFlow', 'vehicleFlow': '25'}},
#   {'@index': '2',
#    'basicDataValue': {'@xsi$type': 'TrafficConcentration',
#     'concentration': '0'}}]}

# %%
from pandas.io.json import json_normalize
pdmeasurements= pd.json_normalize(measurements)
pdmeasurements
# Out:
#      measurementSiteReference measurementTimeDefault  \
# 0                    GH020A_B    2021-12-11T17:00:11
# 1                    GJ3301_D    2021-12-11T17:00:11
# 2                    GH020A_A    2021-12-11T17:00:11
# 3                    GJ3301_C    2021-12-11T17:00:11
# 4                    GJ3301_B    2021-12-11T17:00:11
# ...                       ...                    ...
# 1028                 GG030A_R    2021-12-11T17:00:11
# 1029                 GJ011A_V    2021-12-11T17:00:11
# 1030                 GA4771_V    2021-12-11T17:00:10
# 1031                 GJ011A_T    2021-12-11T17:00:11
# 1032                 GA4771_T    2021-12-11T17:00:10
#
#                                           measuredValue
# 0     [{'@index': '1', 'basicDataValue': {'@xsi$type...
# 1     [{'@index': '1', 'basicDataValue': {'@xsi$type...
# 2     [{'@index': '1', 'basicDataValue': {'@xsi$type...
# 3     [{'@index': '1', 'basicDataValue': {'@xsi$type...
# ...

# %%
alldata=pd.json_normalize(measurements, record_path='measuredValue', meta=['measurementSiteReference'])

# %%
allFlowData=alldata[alldata['basicDataValue.@xsi$type']=='TrafficFlow']
allFlowData.sample(1)
# Out:
#      @index basicDataValue.@xsi$type basicDataValue.vehicleFlow  \
# 1054      1              TrafficFlow                         14
#
#      basicDataValue.concentration measurementSiteReference
# 1054                          NaN                 GI1571_C

# %%
import pandas as pd
allFlowData2=allFlowData[['measurementSiteReference','basicDataValue.vehicleFlow']]
allFlowData2.sample(5)

#make array 
times=pd.Series([data['d2LogicalModel']['payloadPublication']['publicationTime']]*len(allFlowData2.index))
allFlowData2.insert(0,'RecTime',times.values)
ab=allFlowData2.assign(RecTime=times.values)
ab.sample(5)
allFlowData2.sample(5)
# Out:
#                   RecTime measurementSiteReference basicDataValue.vehicleFlow
# 1694  2021-12-11T17:03:10                 GA0651_A                          6
# 1886  2021-12-11T17:03:10                 GJ0141_T                         29
# 902   2021-12-11T17:03:10                 GH4601_H                          0
# 1848  2021-12-11T17:03:10                 GK5101_D                         16
# 1068  2021-12-11T17:03:10                 GH335A_S                         26

# %%
df=allFlowData2.rename(columns={'measurementSiteReference':'Site',"basicDataValue.vehicleFlow":"Flow"})
df['RecTime']=pd.to_datetime(df['RecTime'])

# %% [markdown]
# ### Export to CSV the 2 lists of locations

# %%
allFlowData2.to_csv('locastionsfromobs.csv')
locations.to_csv('locations.csv')

# %%
sitelist = []
data[0]['site']['siteId']

for items in data:
    newdictitem={'lastupdate':items['lastUpdate'],'site':items['site']['siteId'],'flow':items['flow']}
    sitelist.append(newdictitem)

# %%
### Connect to Racle datbase

# %%
import cx_Oracle

con = cx_Oracle.connect('SIMON', 'GodelEscherBach65?', 'db202006252115_high')
cur=con.cursor()

# %%
statement = 'insert into movement values (:1,:2,:3)'
df_list=df.values.tolist()
df_list
# Out:
# [[Timestamp('2021-12-02 20:21:08'), 'GH020A_B', '14'],
#  [Timestamp('2021-12-02 20:21:08'), 'GJ3301_D', '5'],
#  [Timestamp('2021-12-02 20:21:08'), 'GH020A_A', '7'],
#  [Timestamp('2021-12-02 20:21:08'), 'GJ3301_C', '5'],
#  [Timestamp('2021-12-02 20:21:08'), 'GJ3301_B', '4'],
#  [Timestamp('2021-12-02 20:21:08'), 'GJ3301_A', '14'],
#  [Timestamp('2021-12-02 20:21:08'), 'GC2381_T', '0'],
#  [Timestamp('2021-12-02 20:21:08'), 'GC2381_S', '0'],
#  [Timestamp('2021-12-02 20:21:08'), 'GC2381_R', '0'],
#  [Timestamp('2021-12-02 20:21:08'), 'GD2701_D', '0'],
#  [Timestamp('2021-12-02 20:21:08'), 'GD2701_B', '15'],
#  [Timestamp('2021-12-02 20:21:08'), 'GD2701_A', '18'],
#  [Timestamp('2021-12-02 20:21:08'), 'GF0301_D', '0'],
#  [Timestamp('2021-12-02 20:21:08'), 'GF0301_C', '0'],
#  [Timestamp('2021-12-02 20:21:08'), 'GJ275A_V', '18'],
#  [Timestamp('2021-12-02 20:21:08'), 'GF0301_B', '0'],
#  [Timestamp('2021-12-02 20:21:08'), 'GC4151_E', '11'],
# ...

# %%
n=0
for i in df.iterrows():
    cur.execute(statement, df_list[n])
    n+=1 
con.commit()
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# /tmp/ipykernel_3503/4032529734.py in <module>
#       1 n=0
#       2 for i in df.iterrows():
# ----> 3     cur.execute(statement, df_list[n])
#       4     n+=1
#       5 con.commit()
#
# IntegrityError: ORA-00001: unique constraint (SIMON.MOVEMENT_PK) violated

# %%
import psycopg2
import sys
import pandas as pd
from sqlalchemy import create_engine

# Here you want to change your database, username & password according to your own values
param_dic = {
    "host"      : "localhost",
    "database"  : "movement",
    "user"      : "simon",
    "password"  : "Babbage65?"
}

conn_string = 'postgresql+psycopg2://simon:Babbage65?@localhost:5432/movement'
  
db = create_engine(conn_string)
conn = db.connect()

# %%
df.to_sql('movement', con=conn, if_exists='replace' ,index=False)

  
# conn.commit()
conn.close()

# %%
df
# Out:
#                  RecTime    Siteid Flow
# 0    2021-12-11 15:43:10  GH020A_B   28
# 2    2021-12-11 15:43:10  GJ3301_D   10
# 4    2021-12-11 15:43:10  GH020A_A   20
# 6    2021-12-11 15:43:10  GJ3301_C   13
# 8    2021-12-11 15:43:10  GJ3301_B    5
# ...                  ...       ...  ...
# 2056 2021-12-11 15:43:10  GG030A_R   50
# 2058 2021-12-11 15:43:10  GJ011A_V   13
# 2060 2021-12-11 15:43:10  GA4771_V   10
# 2062 2021-12-11 15:43:10  GJ011A_T    0
# 2064 2021-12-11 15:43:10  GA4771_T   19
#
# [1033 rows x 3 columns]

# %%
import pymysql
import sys
from sqlalchemy import create_engine

# Here you want to change your database, username & password according to your own values
param_dic = {
    "host"      : "localhost",
    "database"  : "movement",
    "user"      : "simon",
    "password"  : "Babbage65?"
}

# %%
conn_string = 'mysql+pymysql://simon:Babbage65?@localhost/movement'
  
db = create_engine(conn_string)
conn = db.connect()

df.to_sql('movement', con=conn, if_exists='append', index=False)

  
# conn.commit()
conn.close()
